# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

boston = pd.read_csv('/kaggle/input/dataset-to-perform-regression-and-classification/Boston.csv')
boston
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# ...

# %% [markdown]
# As can be seen, the dataframe contains *506* rows and *14* columns, with the latter being different features that can affect the price of a house, such as tax rate.

# %%
#creating a grid of scatterplots of all pairs of predictors
g = sns.PairGrid(boston)
g.map_upper(plt.scatter, s=3)
g.map_diag(plt.hist)
g.map_lower(plt.scatter)
g.fig.set_size_inches(12, 12)

# %% [markdown]
# > *Are there any predictors, associated with the per capita crime rate? If so, explain the relationship.*
#
# There seems to be a relationship between crim and medv, dis, age, rm. This is checked in the further blocks of code.

# %%
boston.corrwith(boston['crim']).sort_values()
# Out:
# medv      -0.388305
# black     -0.385064
# dis       -0.379670
# rm        -0.219247
# zn        -0.200469
# chas      -0.055892
# ptratio    0.289946
# age        0.352734
# indus      0.406583
# nox        0.420972
# lstat      0.455621
# tax        0.582764
# rad        0.625505
# crim       1.000000
# dtype: float64

# %% [markdown]
# So, there seems to be a positive correlation between crim and rad, tax, lstat, nox, indus, age. The correlations are rather mild.
